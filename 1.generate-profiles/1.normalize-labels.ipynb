# %% [markdown]
# # Normalize Cell Health Labels
#
# **Gregory Way, 2019**

# %%
import os
import numpy as np
from scipy.stats import median_absolute_deviation
import pandas as pd

# %%
# %matplotlib inline

# %%
# Function to scale cell health target variables
def scale(x):
    x_median = np.nanmedian(x)
    x_std = np.nanstd(x)
    x_scale = (x - x_median) / x_std
    return x_scale

# %%
file = os.path.join("data", "labels", "cell_health_labels.tsv")
label_df = pd.read_csv(file, sep='\t')

print(label_df.shape)
label_df.head(2)
# Out:
# (2302, 75)
#   cell_id   guide plate_name  well_col well_row  \
# 0     ES2  AKT1-1    Plate 1         3        A
# 1     ES2  AKT1-1    Plate 1        22        O
#
#    cc_all_high_n_spots_h2ax_mean  cc_all_large_notround_polynuclear_mean  \
# 0                        0.04287                                0.007976
# 1                        0.02635                                0.005988
#
#    cc_all_large_round_polyploid_mean  cc_all_n_objects  cc_all_n_spots_mean  \
# 0                           0.003988              1003                1.777
# 1                           0.005988               835                1.582
#
#    ...  vb_num_live_cells  vb_percent_all_apoptosis  \
# 0  ...             1465.0                   0.02710
# 1  ...             1575.0                   0.03169
#
#    vb_percent_all_early_apoptosis  vb_percent_all_late_apoptosis  \
# 0                         0.01190                        0.01520
# 1                         0.01463                        0.01706
#
#    vb_percent_caspase_dead_only  vb_percent_dead  vb_percent_dead_only  \
# 0                         1.640          0.03173               0.01652
# 1                         1.405          0.03961               0.02255
#
#    vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0           0.9683               NaN          NaN
# 1           0.9598             279.6       2083.0
#
# [2 rows x 75 columns]

# %%
# Some infinite values are present, replace them with NA
label_df = label_df.replace([np.inf, -np.inf], np.nan)

# Apply normalization by plate
normalized_label_df = (
    label_df
    .drop(["guide", "well_col", "well_row"], axis="columns")
    .groupby(["cell_id", "plate_name"])
    .transform(scale)
)

normalized_label_df = pd.concat(
    [
        label_df.loc[:, ["cell_id", "guide", "plate_name", "well_col", "well_row"]],
        normalized_label_df
    ],
    axis="columns"
)

print(normalized_label_df.shape)
normalized_label_df.head(2)
# Out:
# (2302, 75)
#   cell_id   guide plate_name  well_col well_row  \
# 0     ES2  AKT1-1    Plate 1         3        A
# 1     ES2  AKT1-1    Plate 1        22        O
#
#    cc_all_high_n_spots_h2ax_mean  cc_all_large_notround_polynuclear_mean  \
# 0                       0.655229                               -0.565658
# 1                      -0.251336                               -0.816445
#
#    cc_all_large_round_polyploid_mean  cc_all_n_objects  cc_all_n_spots_mean  \
# 0                          -0.839186         -0.513748             0.313600
# 1                          -0.525940         -0.819810            -0.450799
#
#    ...  vb_num_live_cells  vb_percent_all_apoptosis  \
# 0  ...           0.281397                 -0.279051
# 1  ...           0.543716                 -0.221588
#
#    vb_percent_all_early_apoptosis  vb_percent_all_late_apoptosis  \
# 0                       -0.429141                      -0.177258
# 1                       -0.311041                      -0.149198
#
#    vb_percent_caspase_dead_only  vb_percent_dead  vb_percent_dead_only  \
# 0                     -0.920300        -0.139875             -0.016549
# 1                     -1.070176        -0.046783              0.268559
#
#    vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0         0.140570               NaN          NaN
# 1         0.040163          -0.29248     0.008339
#
# [2 rows x 75 columns]

# %%
# Write to file
file = os.path.join("data", "labels", "normalized_cell_health_labels.tsv")
normalized_label_df.to_csv(file, index=False, sep='\t')
